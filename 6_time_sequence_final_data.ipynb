# %% [markdown]
# **Notes:**
# * This code creates a time sequence version of dataset for drug-indication pair over the start and primary completion dates of the trial
# * All the variables are appropriately aggregated over drug-indication pair and date time variable
# * The aggregation of variables is cumulative over time, with first value in the sequence as actual, and then cumulatively aggregating over time in sequential order

# %%
import numpy as np
from scipy import stats
import pandas as pd
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', None)

# %%
# !cp /content/drive/MyDrive/Capstone2024/Datasets/nov_23/merged_df_1123.txt ./

# %%
# Action items on time sequence code -
#     1. move the coding of drug_outcome to 1 and 0 before the cumulative code
#     2. override the success in duplicate cases, instead of dropping (change the idxmax code line)
#     3. gender hot encoding, and then appropriately accumulating based on max value of gender
#     4. for enrollment, the cumulative values based on avg, sum, etc.
#     5. for trial_duration, the cumulative values based on avg, sum, etc.

# %%
# load the big merged table with drugs and multiple trial rows
df_merged_1123_seq = pd.read_csv('merged_df_1123.txt', sep='|')
df_merged_1123_seq.shape
# Out:
# <ipython-input-26-cf253198457d>:2: DtypeWarning: Columns (23,78,126,127) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_merged_1123_seq = pd.read_csv('merged_df_1123.txt', sep='|')
# (24959, 140)

# %%
df_merged_1123_seq.head()
# Out:
#    Unnamed: 0       nct_id intervention_type  \
# 0           0  NCT00606502              DRUG
# 1           1  NCT00606502              DRUG
# 2           2  NCT00606502              DRUG
# 3           3  NCT00606502              DRUG
# 4           4  NCT00606502              DRUG
#
#                                          description trial_drug_cleaned  \
# 0  150 mg orally in tablet form~Administered dail...          erlotinib
# 1  150 mg orally in tablet form~Administered dail...          erlotinib
# 2  150 mg orally in tablet form~Administered dail...          erlotinib
# 3  150 mg orally in tablet form~Administered dail...          erlotinib
# 4  150 mg orally in tablet form~Administered dail...          erlotinib
#
#                    conditions  Drug Name Highest Status  \
# 0  non-small cell lung cancer  erlotinib       Launched
# 1  non-small cell lung cancer  erlotinib       Launched
# 2  non-small cell lung cancer  erlotinib       Launched
# 3  non-small cell lung cancer  erlotinib       Launched
# 4  non-small cell lung cancer  erlotinib       Launched
#
#                                     Other Drug Names       Originator Company  \
# 0  CP-358774; CP-358774-01; NSC-718781; OSI-420; ...  OSI Pharmaceuticals Inc
# 1  CP-358774; CP-358774-01; NSC-718781; OSI-420; ...  OSI Pharmaceuticals Inc
# 2  CP-358774; CP-358774-01; NSC-718781; OSI-420; ...  OSI Pharmaceuticals Inc
# 3  CP-358774; CP-358774-01; NSC-718781; OSI-420; ...  OSI Pharmaceuticals Inc
# 4  CP-358774; CP-358774-01; NSC-718781; OSI-420; ...  OSI Pharmaceuticals Inc
#
#           Originator Company HQ  \
# 0  OSI Pharmaceuticals Inc (US)
# 1  OSI Pharmaceuticals Inc (US)
# 2  OSI Pharmaceuticals Inc (US)
# 3  OSI Pharmaceuticals Inc (US)
# 4  OSI Pharmaceuticals Inc (US)
#
#                                     Active Companies  \
# 0  Astellas Pharma Inc; Baheal Pharmaceutical gro...
# 1  Astellas Pharma Inc; Baheal Pharmaceutical gro...
# 2  Astellas Pharma Inc; Baheal Pharmaceutical gro...
# 3  Astellas Pharma Inc; Baheal Pharmaceutical gro...
# 4  Astellas Pharma Inc; Baheal Pharmaceutical gro...
#
#                                  Active Companies HQ          Therapy Area  \
# 0  Astellas Pharma Inc (Japan); Baheal Pharmaceut...  Cancer; Dermatologic
# 1  Astellas Pharma Inc (Japan); Baheal Pharmaceut...  Cancer; Dermatologic
# 2  Astellas Pharma Inc (Japan); Baheal Pharmaceut...  Cancer; Dermatologic
# 3  Astellas Pharma Inc (Japan); Baheal Pharmaceut...  Cancer; Dermatologic
# 4  Astellas Pharma Inc (Japan); Baheal Pharmaceut...  Cancer; Dermatologic
#
#                                   Active Indications  \
# 0  Acute myelogenous leukemia; Breast tumor; Cent...
# 1  Acute myelogenous leukemia; Breast tumor; Cent...
# 2  Acute myelogenous leukemia; Breast tumor; Cent...
# 3  Acute myelogenous leukemia; Breast tumor; Cent...
# 4  Acute myelogenous leukemia; Breast tumor; Cent...
#
#                                               Action  \
# 0  Anticancer protein kinase inhibitor; EGFR fami...
# 1  Anticancer protein kinase inhibitor; EGFR fami...
# 2  Anticancer protein kinase inhibitor; EGFR fami...
# 3  Anticancer protein kinase inhibitor; EGFR fami...
# 4  Anticancer protein kinase inhibitor; EGFR fami...
#
#                                         Technologies  Regulatory Designations  \
# 0  Film coating; Oral formulation; Small molecule...  Fast Track; Orphan Drug
# 1  Film coating; Oral formulation; Small molecule...  Fast Track; Orphan Drug
# 2  Film coating; Oral formulation; Small molecule...  Fast Track; Orphan Drug
# 3  Film coating; Oral formulation; Small molecule...  Fast Track; Orphan Drug
# 4  Film coating; Oral formulation; Small molecule...  Fast Track; Orphan Drug
#
#                                 Inactive Indications  \
# 0  Cancer; Colorectal tumor; Ependymoma; Esophagu...
# 1  Cancer; Colorectal tumor; Ependymoma; Esophagu...
# 2  Cancer; Colorectal tumor; Ependymoma; Esophagu...
# 3  Cancer; Colorectal tumor; Ependymoma; Esophagu...
# 4  Cancer; Colorectal tumor; Ependymoma; Esophagu...
#
#             Inactive Companies Has Deals Last Change Date  Added Date  \
# 0  Nippon Roche KK; Pfizer Inc       Yes       2024-07-04  1996-03-28
# 1  Nippon Roche KK; Pfizer Inc       Yes       2024-07-04  1996-03-28
# 2  Nippon Roche KK; Pfizer Inc       Yes       2024-07-04  1996-03-28
# 3  Nippon Roche KK; Pfizer Inc       Yes       2024-07-04  1996-03-28
# 4  Nippon Roche KK; Pfizer Inc       Yes       2024-07-04  1996-03-28
#
#   First Launched Date                                            Extract  \
# 0          2004-11-24  Erlotinib (Tarceva; OSI-744; CP-358774; NSC-71...
# 1          2004-11-24  Erlotinib (Tarceva; OSI-744; CP-358774; NSC-71...
# 2          2004-11-24  Erlotinib (Tarceva; OSI-744; CP-358774; NSC-71...
# 3          2004-11-24  Erlotinib (Tarceva; OSI-744; CP-358774; NSC-71...
# 4          2004-11-24  Erlotinib (Tarceva; OSI-744; CP-358774; NSC-71...
#
#    Drug Id cortellis_cleaned_drug  nlm_download_date_description  \
# 0    11961              erlotinib                            NaN
# 1    11961              erlotinib                            NaN
# 2    11961              erlotinib                            NaN
# 3    11961              erlotinib                            NaN
# 4    11961              erlotinib                            NaN
#
#   study_first_submitted_date results_first_submitted_date  \
# 0                 2008-01-22                   2010-12-22
# 1                 2008-01-22                   2010-12-22
# 2                 2008-01-22                   2010-12-22
# 3                 2008-01-22                   2010-12-22
# 4                 2008-01-22                   2010-12-22
#
#   disposition_first_submitted_date last_update_submitted_date  \
# 0                              NaN                 2021-02-08
# 1                              NaN                 2021-02-08
# 2                              NaN                 2021-02-08
# 3                              NaN                 2021-02-08
# 4                              NaN                 2021-02-08
#
#   study_first_submitted_qc_date study_first_posted_date  \
# 0                    2008-02-01              2008-02-04
# 1                    2008-02-01              2008-02-04
# 2                    2008-02-01              2008-02-04
# 3                    2008-02-01              2008-02-04
# 4                    2008-02-01              2008-02-04
#
#   study_first_posted_date_type results_first_submitted_qc_date  \
# 0                    ESTIMATED                      2010-12-22
# 1                    ESTIMATED                      2010-12-22
# 2                    ESTIMATED                      2010-12-22
# 3                    ESTIMATED                      2010-12-22
# 4                    ESTIMATED                      2010-12-22
#
#   results_first_posted_date results_first_posted_date_type  \
# 0                2011-01-20                      ESTIMATED
# 1                2011-01-20                      ESTIMATED
# 2                2011-01-20                      ESTIMATED
# 3                2011-01-20                      ESTIMATED
# 4                2011-01-20                      ESTIMATED
#
#   disposition_first_submitted_qc_date disposition_first_posted_date  \
# 0                                 NaN                           NaN
# 1                                 NaN                           NaN
# 2                                 NaN                           NaN
# 3                                 NaN                           NaN
# 4                                 NaN                           NaN
#
#   disposition_first_posted_date_type last_update_submitted_qc_date  \
# 0                                NaN                    2021-02-08
# 1                                NaN                    2021-02-08
# 2                                NaN                    2021-02-08
# 3                                NaN                    2021-02-08
# 4                                NaN                    2021-02-08
#
#   last_update_posted_date last_update_posted_date_type start_month_year  \
# 0              2021-03-05                       ACTUAL          2008-01
# 1              2021-03-05                       ACTUAL          2008-01
# 2              2021-03-05                       ACTUAL          2008-01
# 3              2021-03-05                       ACTUAL          2008-01
# 4              2021-03-05                       ACTUAL          2008-01
#
#   start_date_type  start_date verification_month_year verification_date  \
# 0             NaN  2008-01-31                 2021-02        2021-02-28
# 1             NaN  2008-01-31                 2021-02        2021-02-28
# 2             NaN  2008-01-31                 2021-02        2021-02-28
# 3             NaN  2008-01-31                 2021-02        2021-02-28
# 4             NaN  2008-01-31                 2021-02        2021-02-28
#
#   completion_month_year completion_date_type completion_date  \
# 0            2010-06-24               ACTUAL      2010-06-24
# 1            2010-06-24               ACTUAL      2010-06-24
# 2            2010-06-24               ACTUAL      2010-06-24
# 3            2010-06-24               ACTUAL      2010-06-24
# 4            2010-06-24               ACTUAL      2010-06-24
#
#   primary_completion_month_year primary_completion_date_type  \
# 0                    2010-06-24                       ACTUAL
# 1                    2010-06-24                       ACTUAL
# 2                    2010-06-24                       ACTUAL
# 3                    2010-06-24                       ACTUAL
# 4                    2010-06-24                       ACTUAL
#
#   primary_completion_date  target_duration      study_type acronym  \
# 0              2010-06-24              NaN  INTERVENTIONAL     NaN
# 1              2010-06-24              NaN  INTERVENTIONAL     NaN
# 2              2010-06-24              NaN  INTERVENTIONAL     NaN
# 3              2010-06-24              NaN  INTERVENTIONAL     NaN
# 4              2010-06-24              NaN  INTERVENTIONAL     NaN
#
#   baseline_population                                        brief_title  \
# 0                 NaN  Study of Pralatrexate vs. Erlotinib for Non-Sm...
# 1                 NaN  Study of Pralatrexate vs. Erlotinib for Non-Sm...
# 2                 NaN  Study of Pralatrexate vs. Erlotinib for Non-Sm...
# 3                 NaN  Study of Pralatrexate vs. Erlotinib for Non-Sm...
# 4                 NaN  Study of Pralatrexate vs. Erlotinib for Non-Sm...
#
#                                       official_title overall_status  \
# 0  A Randomized, Phase 2b, Multi-center Study of ...      COMPLETED
# 1  A Randomized, Phase 2b, Multi-center Study of ...      COMPLETED
# 2  A Randomized, Phase 2b, Multi-center Study of ...      COMPLETED
# 3  A Randomized, Phase 2b, Multi-center Study of ...      COMPLETED
# 4  A Randomized, Phase 2b, Multi-center Study of ...      COMPLETED
#
#    last_known_status   phase  enrollment enrollment_type  \
# 0                NaN  PHASE2       201.0          ACTUAL
# 1                NaN  PHASE2       201.0          ACTUAL
# 2                NaN  PHASE2       201.0          ACTUAL
# 3                NaN  PHASE2       201.0          ACTUAL
# 4                NaN  PHASE2       201.0          ACTUAL
#
#                           source  \
# 0  Spectrum Pharmaceuticals, Inc
# 1  Spectrum Pharmaceuticals, Inc
# 2  Spectrum Pharmaceuticals, Inc
# 3  Spectrum Pharmaceuticals, Inc
# 4  Spectrum Pharmaceuticals, Inc
#
#                              limitations_and_caveats  number_of_arms  \
# 0  The date of the CRF database cut-off for patie...             2.0
# 1  The date of the CRF database cut-off for patie...             2.0
# 2  The date of the CRF database cut-off for patie...             2.0
# 3  The date of the CRF database cut-off for patie...             2.0
# 4  The date of the CRF database cut-off for patie...             2.0
#
#    number_of_groups why_stopped has_expanded_access  \
# 0               NaN         NaN                   f
# 1               NaN         NaN                   f
# 2               NaN         NaN                   f
# 3               NaN         NaN                   f
# 4               NaN         NaN                   f
#
#    expanded_access_type_individual  expanded_access_type_intermediate  \
# 0                              NaN                                NaN
# 1                              NaN                                NaN
# 2                              NaN                                NaN
# 3                              NaN                                NaN
# 4                              NaN                                NaN
#
#    expanded_access_type_treatment has_dmc is_fda_regulated_drug  \
# 0                             NaN     NaN                   NaN
# 1                             NaN     NaN                   NaN
# 2                             NaN     NaN                   NaN
# 3                             NaN     NaN                   NaN
# 4                             NaN     NaN                   NaN
#
#   is_fda_regulated_device is_unapproved_device  is_ppsd is_us_export  \
# 0                     NaN                  NaN      NaN          NaN
# 1                     NaN                  NaN      NaN          NaN
# 2                     NaN                  NaN      NaN          NaN
# 3                     NaN                  NaN      NaN          NaN
# 4                     NaN                  NaN      NaN          NaN
#
#    biospec_retention  biospec_description ipd_time_frame ipd_access_criteria  \
# 0                NaN                  NaN            NaN                 NaN
# 1                NaN                  NaN            NaN                 NaN
# 2                NaN                  NaN            NaN                 NaN
# 3                NaN                  NaN            NaN                 NaN
# 4                NaN                  NaN            NaN                 NaN
#
#   ipd_url plan_to_share_ipd plan_to_share_ipd_description  \
# 0     NaN               NaN                           NaN
# 1     NaN               NaN                           NaN
# 2     NaN               NaN                           NaN
# 3     NaN               NaN                           NaN
# 4     NaN               NaN                           NaN
#
#                    created_at                  updated_at source_class  \
# 0  2024-08-04 13:24:13.009685  2024-08-04 13:24:13.009685     INDUSTRY
# 1  2024-08-04 13:24:13.009685  2024-08-04 13:24:13.009685     INDUSTRY
# 2  2024-08-04 13:24:13.009685  2024-08-04 13:24:13.009685     INDUSTRY
# 3  2024-08-04 13:24:13.009685  2024-08-04 13:24:13.009685     INDUSTRY
# 4  2024-08-04 13:24:13.009685  2024-08-04 13:24:13.009685     INDUSTRY
#
#    delayed_posting expanded_access_nctid expanded_access_status_for_nctid  \
# 0              NaN                   NaN                              NaN
# 1              NaN                   NaN                              NaN
# 2              NaN                   NaN                              NaN
# 3              NaN                   NaN                              NaN
# 4              NaN                   NaN                              NaN
#
#    fdaaa801_violation  baseline_type_units_analyzed  patient_registry  \
# 0                 NaN                           NaN               NaN
# 1                 NaN                           NaN               NaN
# 2                 NaN                           NaN               NaN
# 3                 NaN                           NaN               NaN
# 4                 NaN                           NaN               NaN
#
#   drug_outcome          disease_type new_therapy_area      id_x  \
# 0      success  Lung, Non-Small Cell         Oncology  29671336
# 1      success  Lung, Non-Small Cell         Oncology  29671336
# 2      success  Lung, Non-Small Cell         Oncology  29671336
# 3      success  Lung, Non-Small Cell         Oncology  29671336
# 4      success  Lung, Non-Small Cell         Oncology  29671336
#
#    number_of_facilities  number_of_nsae_subjects  number_of_sae_subjects  \
# 0                  47.0                    540.0                   124.0
# 1                  47.0                    540.0                   124.0
# 2                  47.0                    540.0                   124.0
# 3                  47.0                    540.0                   124.0
# 4                  47.0                    540.0                   124.0
#
#    registered_in_calendar_year  nlm_download_date  actual_duration  \
# 0                         2008                NaN             29.0
# 1                         2008                NaN             29.0
# 2                         2008                NaN             29.0
# 3                         2008                NaN             29.0
# 4                         2008                NaN             29.0
#
#   were_results_reported  months_to_report_results has_us_facility  \
# 0                     t                       6.0               t
# 1                     t                       6.0               t
# 2                     t                       6.0               t
# 3                     t                       6.0               t
# 4                     t                       6.0               t
#
#   has_single_facility  minimum_age_num  maximum_age_num minimum_age_unit  \
# 0                   f             18.0              NaN            Years
# 1                   f             18.0              NaN            Years
# 2                   f             18.0              NaN            Years
# 3                   f             18.0              NaN            Years
# 4                   f             18.0              NaN            Years
#
#   maximum_age_unit  number_of_primary_outcomes_to_measure  \
# 0              NaN                                    1.0
# 1              NaN                                    1.0
# 2              NaN                                    1.0
# 3              NaN                                    1.0
# 4              NaN                                    1.0
#
#    number_of_secondary_outcomes_to_measure  \
# 0                                      3.0
# 1                                      3.0
# 2                                      3.0
# 3                                      3.0
# 4                                      3.0
#
#    number_of_other_outcomes_to_measure     id_y  sampling_method gender  \
# 0                                  NaN  7316876              NaN    ALL
# 1                                  NaN  7316876              NaN    ALL
# 2                                  NaN  7316876              NaN    ALL
# 3                                  NaN  7316876              NaN    ALL
# 4                                  NaN  7316876              NaN    ALL
#
#   minimum_age maximum_age healthy_volunteers  population  \
# 0    18 Years         NaN                  f         NaN
# 1    18 Years         NaN                  f         NaN
# 2    18 Years         NaN                  f         NaN
# 3    18 Years         NaN                  f         NaN
# 4    18 Years         NaN                  f         NaN
#
#                                             criteria gender_description  \
# 0  Inclusion Criteria:~* Confirmed Stage IIIB/ IV...                NaN
# 1  Inclusion Criteria:~* Confirmed Stage IIIB/ IV...                NaN
# 2  Inclusion Criteria:~* Confirmed Stage IIIB/ IV...                NaN
# 3  Inclusion Criteria:~* Confirmed Stage IIIB/ IV...                NaN
# 4  Inclusion Criteria:~* Confirmed Stage IIIB/ IV...                NaN
#
#   gender_based adult child older_adult   official_role        official_name  \
# 0          NaN     t     f           t  STUDY_DIRECTOR  Garry Weems, PharmD
# 1          NaN     t     f           t  STUDY_DIRECTOR  Garry Weems, PharmD
# 2          NaN     t     f           t  STUDY_DIRECTOR  Garry Weems, PharmD
# 3          NaN     t     f           t  STUDY_DIRECTOR  Garry Weems, PharmD
# 4          NaN     t     f           t  STUDY_DIRECTOR  Garry Weems, PharmD
#
#             official_affiliation        id   trial_country country_removed  \
# 0  Spectrum Pharmaceuticals, Inc  10138299  Czech Republic               t
# 1  Spectrum Pharmaceuticals, Inc  10138896   United States               f
# 2  Spectrum Pharmaceuticals, Inc  10138897       Argentina               f
# 3  Spectrum Pharmaceuticals, Inc  10138898          Brazil               f
# 4  Spectrum Pharmaceuticals, Inc  10138899         Czechia               f
#
#    LLM_GBT_4o_Human_Importance_Ratings  LLama3_2_Criteria_Robustness  \
# 0                                  1.0                           2.0
# 1                                  1.0                           2.0
# 2                                  1.0                           2.0
# 3                                  1.0                           2.0
# 4                                  1.0                           2.0
#
#    Spacy_Pregnant_Women_Excluded
# 0                            1.0
# 1                            1.0
# 2                            1.0
# 3                            1.0
# 4                            1.0

# %%
# calculate days from first start date of any trial of the drug-disease pair to the
# primary completion date of current trial
df_merged_1123_seq[['start_date_norm', 'primary_completion_date_norm']] = df_merged_1123_seq[
    ['start_month_year', 'primary_completion_date']].apply(
    lambda col: col.fillna('').apply(
      lambda x: x + '-15' if len(x) == 7 else x
    ).pipe(pd.to_datetime)
)

df_merged_1123_seq = df_merged_1123_seq.pipe(
    lambda x: x.merge(
        x.groupby([
            'trial_drug_cleaned', 'disease_type'
        ]).start_date_norm.min().rename('start_date_first').reset_index()
    )
).eval(
    'days_since_first_start = (primary_completion_date_norm - start_date_first).dt.days'
)

df_merged_1123_seq.head()
# Out:
#    Unnamed: 0       nct_id intervention_type  \
# 0           0  NCT00606502              DRUG
# 1           1  NCT00606502              DRUG
# 2           2  NCT00606502              DRUG
# 3           3  NCT00606502              DRUG
# 4           4  NCT00606502              DRUG
#
#                                          description trial_drug_cleaned  \
# 0  150 mg orally in tablet form~Administered dail...          erlotinib
# 1  150 mg orally in tablet form~Administered dail...          erlotinib
# 2  150 mg orally in tablet form~Administered dail...          erlotinib
# 3  150 mg orally in tablet form~Administered dail...          erlotinib
# 4  150 mg orally in tablet form~Administered dail...          erlotinib
#
#                    conditions  Drug Name Highest Status  \
# 0  non-small cell lung cancer  erlotinib       Launched
# 1  non-small cell lung cancer  erlotinib       Launched
# 2  non-small cell lung cancer  erlotinib       Launched
# 3  non-small cell lung cancer  erlotinib       Launched
# 4  non-small cell lung cancer  erlotinib       Launched
#
#                                     Other Drug Names       Originator Company  \
# 0  CP-358774; CP-358774-01; NSC-718781; OSI-420; ...  OSI Pharmaceuticals Inc
# 1  CP-358774; CP-358774-01; NSC-718781; OSI-420; ...  OSI Pharmaceuticals Inc
# 2  CP-358774; CP-358774-01; NSC-718781; OSI-420; ...  OSI Pharmaceuticals Inc
# 3  CP-358774; CP-358774-01; NSC-718781; OSI-420; ...  OSI Pharmaceuticals Inc
# 4  CP-358774; CP-358774-01; NSC-718781; OSI-420; ...  OSI Pharmaceuticals Inc
#
#           Originator Company HQ  \
# 0  OSI Pharmaceuticals Inc (US)
# 1  OSI Pharmaceuticals Inc (US)
# 2  OSI Pharmaceuticals Inc (US)
# 3  OSI Pharmaceuticals Inc (US)
# 4  OSI Pharmaceuticals Inc (US)
#
#                                     Active Companies  \
# 0  Astellas Pharma Inc; Baheal Pharmaceutical gro...
# 1  Astellas Pharma Inc; Baheal Pharmaceutical gro...
# 2  Astellas Pharma Inc; Baheal Pharmaceutical gro...
# 3  Astellas Pharma Inc; Baheal Pharmaceutical gro...
# 4  Astellas Pharma Inc; Baheal Pharmaceutical gro...
#
#                                  Active Companies HQ          Therapy Area  \
# 0  Astellas Pharma Inc (Japan); Baheal Pharmaceut...  Cancer; Dermatologic
# 1  Astellas Pharma Inc (Japan); Baheal Pharmaceut...  Cancer; Dermatologic
# 2  Astellas Pharma Inc (Japan); Baheal Pharmaceut...  Cancer; Dermatologic
# 3  Astellas Pharma Inc (Japan); Baheal Pharmaceut...  Cancer; Dermatologic
# 4  Astellas Pharma Inc (Japan); Baheal Pharmaceut...  Cancer; Dermatologic
#
#                                   Active Indications  \
# 0  Acute myelogenous leukemia; Breast tumor; Cent...
# 1  Acute myelogenous leukemia; Breast tumor; Cent...
# 2  Acute myelogenous leukemia; Breast tumor; Cent...
# 3  Acute myelogenous leukemia; Breast tumor; Cent...
# 4  Acute myelogenous leukemia; Breast tumor; Cent...
#
#                                               Action  \
# 0  Anticancer protein kinase inhibitor; EGFR fami...
# 1  Anticancer protein kinase inhibitor; EGFR fami...
# 2  Anticancer protein kinase inhibitor; EGFR fami...
# 3  Anticancer protein kinase inhibitor; EGFR fami...
# 4  Anticancer protein kinase inhibitor; EGFR fami...
#
#                                         Technologies  Regulatory Designations  \
# 0  Film coating; Oral formulation; Small molecule...  Fast Track; Orphan Drug
# 1  Film coating; Oral formulation; Small molecule...  Fast Track; Orphan Drug
# 2  Film coating; Oral formulation; Small molecule...  Fast Track; Orphan Drug
# 3  Film coating; Oral formulation; Small molecule...  Fast Track; Orphan Drug
# 4  Film coating; Oral formulation; Small molecule...  Fast Track; Orphan Drug
#
#                                 Inactive Indications  \
# 0  Cancer; Colorectal tumor; Ependymoma; Esophagu...
# 1  Cancer; Colorectal tumor; Ependymoma; Esophagu...
# 2  Cancer; Colorectal tumor; Ependymoma; Esophagu...
# 3  Cancer; Colorectal tumor; Ependymoma; Esophagu...
# 4  Cancer; Colorectal tumor; Ependymoma; Esophagu...
#
#             Inactive Companies Has Deals Last Change Date  Added Date  \
# 0  Nippon Roche KK; Pfizer Inc       Yes       2024-07-04  1996-03-28
# 1  Nippon Roche KK; Pfizer Inc       Yes       2024-07-04  1996-03-28
# 2  Nippon Roche KK; Pfizer Inc       Yes       2024-07-04  1996-03-28
# 3  Nippon Roche KK; Pfizer Inc       Yes       2024-07-04  1996-03-28
# 4  Nippon Roche KK; Pfizer Inc       Yes       2024-07-04  1996-03-28
#
#   First Launched Date                                            Extract  \
# 0          2004-11-24  Erlotinib (Tarceva; OSI-744; CP-358774; NSC-71...
# 1          2004-11-24  Erlotinib (Tarceva; OSI-744; CP-358774; NSC-71...
# 2          2004-11-24  Erlotinib (Tarceva; OSI-744; CP-358774; NSC-71...
# 3          2004-11-24  Erlotinib (Tarceva; OSI-744; CP-358774; NSC-71...
# 4          2004-11-24  Erlotinib (Tarceva; OSI-744; CP-358774; NSC-71...
#
#    Drug Id cortellis_cleaned_drug  nlm_download_date_description  \
# 0    11961              erlotinib                            NaN
# 1    11961              erlotinib                            NaN
# 2    11961              erlotinib                            NaN
# 3    11961              erlotinib                            NaN
# 4    11961              erlotinib                            NaN
#
#   study_first_submitted_date results_first_submitted_date  \
# 0                 2008-01-22                   2010-12-22
# 1                 2008-01-22                   2010-12-22
# 2                 2008-01-22                   2010-12-22
# 3                 2008-01-22                   2010-12-22
# 4                 2008-01-22                   2010-12-22
#
#   disposition_first_submitted_date last_update_submitted_date  \
# 0                              NaN                 2021-02-08
# 1                              NaN                 2021-02-08
# 2                              NaN                 2021-02-08
# 3                              NaN                 2021-02-08
# 4                              NaN                 2021-02-08
#
#   study_first_submitted_qc_date study_first_posted_date  \
# 0                    2008-02-01              2008-02-04
# 1                    2008-02-01              2008-02-04
# 2                    2008-02-01              2008-02-04
# 3                    2008-02-01              2008-02-04
# 4                    2008-02-01              2008-02-04
#
#   study_first_posted_date_type results_first_submitted_qc_date  \
# 0                    ESTIMATED                      2010-12-22
# 1                    ESTIMATED                      2010-12-22
# 2                    ESTIMATED                      2010-12-22
# 3                    ESTIMATED                      2010-12-22
# 4                    ESTIMATED                      2010-12-22
#
#   results_first_posted_date results_first_posted_date_type  \
# 0                2011-01-20                      ESTIMATED
# 1                2011-01-20                      ESTIMATED
# 2                2011-01-20                      ESTIMATED
# 3                2011-01-20                      ESTIMATED
# 4                2011-01-20                      ESTIMATED
#
#   disposition_first_submitted_qc_date disposition_first_posted_date  \
# 0                                 NaN                           NaN
# 1                                 NaN                           NaN
# 2                                 NaN                           NaN
# 3                                 NaN                           NaN
# 4                                 NaN                           NaN
#
#   disposition_first_posted_date_type last_update_submitted_qc_date  \
# 0                                NaN                    2021-02-08
# 1                                NaN                    2021-02-08
# 2                                NaN                    2021-02-08
# 3                                NaN                    2021-02-08
# 4                                NaN                    2021-02-08
#
#   last_update_posted_date last_update_posted_date_type start_month_year  \
# 0              2021-03-05                       ACTUAL          2008-01
# 1              2021-03-05                       ACTUAL          2008-01
# 2              2021-03-05                       ACTUAL          2008-01
# 3              2021-03-05                       ACTUAL          2008-01
# 4              2021-03-05                       ACTUAL          2008-01
#
#   start_date_type  start_date verification_month_year verification_date  \
# 0             NaN  2008-01-31                 2021-02        2021-02-28
# 1             NaN  2008-01-31                 2021-02        2021-02-28
# 2             NaN  2008-01-31                 2021-02        2021-02-28
# 3             NaN  2008-01-31                 2021-02        2021-02-28
# 4             NaN  2008-01-31                 2021-02        2021-02-28
#
#   completion_month_year completion_date_type completion_date  \
# 0            2010-06-24               ACTUAL      2010-06-24
# 1            2010-06-24               ACTUAL      2010-06-24
# 2            2010-06-24               ACTUAL      2010-06-24
# 3            2010-06-24               ACTUAL      2010-06-24
# 4            2010-06-24               ACTUAL      2010-06-24
#
#   primary_completion_month_year primary_completion_date_type  \
# 0                    2010-06-24                       ACTUAL
# 1                    2010-06-24                       ACTUAL
# 2                    2010-06-24                       ACTUAL
# 3                    2010-06-24                       ACTUAL
# 4                    2010-06-24                       ACTUAL
#
#   primary_completion_date  target_duration      study_type acronym  \
# 0              2010-06-24              NaN  INTERVENTIONAL     NaN
# 1              2010-06-24              NaN  INTERVENTIONAL     NaN
# 2              2010-06-24              NaN  INTERVENTIONAL     NaN
# 3              2010-06-24              NaN  INTERVENTIONAL     NaN
# 4              2010-06-24              NaN  INTERVENTIONAL     NaN
#
#   baseline_population                                        brief_title  \
# 0                 NaN  Study of Pralatrexate vs. Erlotinib for Non-Sm...
# 1                 NaN  Study of Pralatrexate vs. Erlotinib for Non-Sm...
# 2                 NaN  Study of Pralatrexate vs. Erlotinib for Non-Sm...
# 3                 NaN  Study of Pralatrexate vs. Erlotinib for Non-Sm...
# 4                 NaN  Study of Pralatrexate vs. Erlotinib for Non-Sm...
#
#                                       official_title overall_status  \
# 0  A Randomized, Phase 2b, Multi-center Study of ...      COMPLETED
# 1  A Randomized, Phase 2b, Multi-center Study of ...      COMPLETED
# 2  A Randomized, Phase 2b, Multi-center Study of ...      COMPLETED
# 3  A Randomized, Phase 2b, Multi-center Study of ...      COMPLETED
# 4  A Randomized, Phase 2b, Multi-center Study of ...      COMPLETED
#
#    last_known_status   phase  enrollment enrollment_type  \
# 0                NaN  PHASE2       201.0          ACTUAL
# 1                NaN  PHASE2       201.0          ACTUAL
# 2                NaN  PHASE2       201.0          ACTUAL
# 3                NaN  PHASE2       201.0          ACTUAL
# 4                NaN  PHASE2       201.0          ACTUAL
#
#                           source  \
# 0  Spectrum Pharmaceuticals, Inc
# 1  Spectrum Pharmaceuticals, Inc
# 2  Spectrum Pharmaceuticals, Inc
# 3  Spectrum Pharmaceuticals, Inc
# 4  Spectrum Pharmaceuticals, Inc
#
#                              limitations_and_caveats  number_of_arms  \
# 0  The date of the CRF database cut-off for patie...             2.0
# 1  The date of the CRF database cut-off for patie...             2.0
# 2  The date of the CRF database cut-off for patie...             2.0
# 3  The date of the CRF database cut-off for patie...             2.0
# 4  The date of the CRF database cut-off for patie...             2.0
#
#    number_of_groups why_stopped has_expanded_access  \
# 0               NaN         NaN                   f
# 1               NaN         NaN                   f
# 2               NaN         NaN                   f
# 3               NaN         NaN                   f
# 4               NaN         NaN                   f
#
#    expanded_access_type_individual  expanded_access_type_intermediate  \
# 0                              NaN                                NaN
# 1                              NaN                                NaN
# 2                              NaN                                NaN
# 3                              NaN                                NaN
# 4                              NaN                                NaN
#
#    expanded_access_type_treatment has_dmc is_fda_regulated_drug  \
# 0                             NaN     NaN                   NaN
# 1                             NaN     NaN                   NaN
# 2                             NaN     NaN                   NaN
# 3                             NaN     NaN                   NaN
# 4                             NaN     NaN                   NaN
#
#   is_fda_regulated_device is_unapproved_device  is_ppsd is_us_export  \
# 0                     NaN                  NaN      NaN          NaN
# 1                     NaN                  NaN      NaN          NaN
# 2                     NaN                  NaN      NaN          NaN
# 3                     NaN                  NaN      NaN          NaN
# 4                     NaN                  NaN      NaN          NaN
#
#    biospec_retention  biospec_description ipd_time_frame ipd_access_criteria  \
# 0                NaN                  NaN            NaN                 NaN
# 1                NaN                  NaN            NaN                 NaN
# 2                NaN                  NaN            NaN                 NaN
# 3                NaN                  NaN            NaN                 NaN
# 4                NaN                  NaN            NaN                 NaN
#
#   ipd_url plan_to_share_ipd plan_to_share_ipd_description  \
# 0     NaN               NaN                           NaN
# 1     NaN               NaN                           NaN
# 2     NaN               NaN                           NaN
# 3     NaN               NaN                           NaN
# 4     NaN               NaN                           NaN
#
#                    created_at                  updated_at source_class  \
# 0  2024-08-04 13:24:13.009685  2024-08-04 13:24:13.009685     INDUSTRY
# 1  2024-08-04 13:24:13.009685  2024-08-04 13:24:13.009685     INDUSTRY
# 2  2024-08-04 13:24:13.009685  2024-08-04 13:24:13.009685     INDUSTRY
# 3  2024-08-04 13:24:13.009685  2024-08-04 13:24:13.009685     INDUSTRY
# 4  2024-08-04 13:24:13.009685  2024-08-04 13:24:13.009685     INDUSTRY
#
#    delayed_posting expanded_access_nctid expanded_access_status_for_nctid  \
# 0              NaN                   NaN                              NaN
# 1              NaN                   NaN                              NaN
# 2              NaN                   NaN                              NaN
# 3              NaN                   NaN                              NaN
# 4              NaN                   NaN                              NaN
#
#    fdaaa801_violation  baseline_type_units_analyzed  patient_registry  \
# 0                 NaN                           NaN               NaN
# 1                 NaN                           NaN               NaN
# 2                 NaN                           NaN               NaN
# 3                 NaN                           NaN               NaN
# 4                 NaN                           NaN               NaN
#
#   drug_outcome          disease_type new_therapy_area      id_x  \
# 0      success  Lung, Non-Small Cell         Oncology  29671336
# 1      success  Lung, Non-Small Cell         Oncology  29671336
# 2      success  Lung, Non-Small Cell         Oncology  29671336
# 3      success  Lung, Non-Small Cell         Oncology  29671336
# 4      success  Lung, Non-Small Cell         Oncology  29671336
#
#    number_of_facilities  number_of_nsae_subjects  number_of_sae_subjects  \
# 0                  47.0                    540.0                   124.0
# 1                  47.0                    540.0                   124.0
# 2                  47.0                    540.0                   124.0
# 3                  47.0                    540.0                   124.0
# 4                  47.0                    540.0                   124.0
#
#    registered_in_calendar_year  nlm_download_date  actual_duration  \
# 0                         2008                NaN             29.0
# 1                         2008                NaN             29.0
# 2                         2008                NaN             29.0
# 3                         2008                NaN             29.0
# 4                         2008                NaN             29.0
#
#   were_results_reported  months_to_report_results has_us_facility  \
# 0                     t                       6.0               t
# 1                     t                       6.0               t
# 2                     t                       6.0               t
# 3                     t                       6.0               t
# 4                     t                       6.0               t
#
#   has_single_facility  minimum_age_num  maximum_age_num minimum_age_unit  \
# 0                   f             18.0              NaN            Years
# 1                   f             18.0              NaN            Years
# 2                   f             18.0              NaN            Years
# 3                   f             18.0              NaN            Years
# 4                   f             18.0              NaN            Years
#
#   maximum_age_unit  number_of_primary_outcomes_to_measure  \
# 0              NaN                                    1.0
# 1              NaN                                    1.0
# 2              NaN                                    1.0
# 3              NaN                                    1.0
# 4              NaN                                    1.0
#
#    number_of_secondary_outcomes_to_measure  \
# 0                                      3.0
# 1                                      3.0
# 2                                      3.0
# 3                                      3.0
# 4                                      3.0
#
#    number_of_other_outcomes_to_measure     id_y  sampling_method gender  \
# 0                                  NaN  7316876              NaN    ALL
# 1                                  NaN  7316876              NaN    ALL
# 2                                  NaN  7316876              NaN    ALL
# 3                                  NaN  7316876              NaN    ALL
# 4                                  NaN  7316876              NaN    ALL
#
#   minimum_age maximum_age healthy_volunteers  population  \
# 0    18 Years         NaN                  f         NaN
# 1    18 Years         NaN                  f         NaN
# 2    18 Years         NaN                  f         NaN
# 3    18 Years         NaN                  f         NaN
# 4    18 Years         NaN                  f         NaN
#
#                                             criteria gender_description  \
# 0  Inclusion Criteria:~* Confirmed Stage IIIB/ IV...                NaN
# 1  Inclusion Criteria:~* Confirmed Stage IIIB/ IV...                NaN
# 2  Inclusion Criteria:~* Confirmed Stage IIIB/ IV...                NaN
# 3  Inclusion Criteria:~* Confirmed Stage IIIB/ IV...                NaN
# 4  Inclusion Criteria:~* Confirmed Stage IIIB/ IV...                NaN
#
#   gender_based adult child older_adult   official_role        official_name  \
# 0          NaN     t     f           t  STUDY_DIRECTOR  Garry Weems, PharmD
# 1          NaN     t     f           t  STUDY_DIRECTOR  Garry Weems, PharmD
# 2          NaN     t     f           t  STUDY_DIRECTOR  Garry Weems, PharmD
# 3          NaN     t     f           t  STUDY_DIRECTOR  Garry Weems, PharmD
# 4          NaN     t     f           t  STUDY_DIRECTOR  Garry Weems, PharmD
#
#             official_affiliation        id   trial_country country_removed  \
# 0  Spectrum Pharmaceuticals, Inc  10138299  Czech Republic               t
# 1  Spectrum Pharmaceuticals, Inc  10138896   United States               f
# 2  Spectrum Pharmaceuticals, Inc  10138897       Argentina               f
# 3  Spectrum Pharmaceuticals, Inc  10138898          Brazil               f
# 4  Spectrum Pharmaceuticals, Inc  10138899         Czechia               f
#
#    LLM_GBT_4o_Human_Importance_Ratings  LLama3_2_Criteria_Robustness  \
# 0                                  1.0                           2.0
# 1                                  1.0                           2.0
# 2                                  1.0                           2.0
# 3                                  1.0                           2.0
# 4                                  1.0                           2.0
#
#    Spacy_Pregnant_Women_Excluded start_date_norm primary_completion_date_norm  \
# 0                            1.0      2008-01-15                   2010-06-24
# 1                            1.0      2008-01-15                   2010-06-24
# 2                            1.0      2008-01-15                   2010-06-24
# 3                            1.0      2008-01-15                   2010-06-24
# 4                            1.0      2008-01-15                   2010-06-24
#
#   start_date_first  days_since_first_start
# 0       2004-11-15                    2047
# 1       2004-11-15                    2047
# 2       2004-11-15                    2047
# 3       2004-11-15                    2047
# 4       2004-11-15                    2047

# %%
df_merged_1123_seq = df_merged_1123_seq.replace(
    {'drug_outcome': {'failure': 0, 'success': 1}}
).pipe(
    lambda df: df.drop(columns='drug_outcome').merge(
        df.groupby(['trial_drug_cleaned', 'disease_type'])['drug_outcome'].max().reset_index()
    )
)
# Out:
# <ipython-input-28-d143a3d7f47d>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_merged_1123_seq = df_merged_1123_seq.replace(

# %%
# replace NaN with median enrollment
df_merged_1123_seq['enrollment'] = df_merged_1123_seq['enrollment'].fillna(df_merged_1123_seq['enrollment'].median())

# %%
# replace NaN with avg actual trial duration
df_merged_1123_seq['actual_duration'] = df_merged_1123_seq['actual_duration'].fillna(df_merged_1123_seq['actual_duration'].mean())

# %%
# replace NaN with 1 in number_of_primary_outcomes_to_measure
df_merged_1123_seq['number_of_primary_outcomes_to_measure'] = df_merged_1123_seq['number_of_primary_outcomes_to_measure'].fillna(1)

# %%
# replace NaN with 0 in number_of_secondary_outcomes_to_measure
df_merged_1123_seq['number_of_secondary_outcomes_to_measure'] = df_merged_1123_seq['number_of_secondary_outcomes_to_measure'].fillna(0)

# %%
# replace NaN with 1 in number_of_arms
df_merged_1123_seq['number_of_arms'] = df_merged_1123_seq['number_of_arms'].fillna(1)

# %%
# encode adult and child flags with 1 and 0
df_merged_1123_seq['adult'] = np.where(df_merged_1123_seq['adult'] == 't', 1, 0)
df_merged_1123_seq['child'] = np.where(df_merged_1123_seq['child'] == 't', 1, 0)

# %%
# replace NaN with false in US facility
df_merged_1123_seq['has_us_facility'] = df_merged_1123_seq['has_us_facility'].fillna('f')

# %%
# encode single and US facility flags with 1 and 0
df_merged_1123_seq['has_single_facility'] = np.where(df_merged_1123_seq['has_single_facility'] == 't', 1, 0)
df_merged_1123_seq['has_us_facility'] = np.where(df_merged_1123_seq['has_us_facility'] == 't', 1, 0)

# %%
# encode healthy_volunteers flags with 1 and 0
df_merged_1123_seq['healthy_volunteers'] = np.where(df_merged_1123_seq['healthy_volunteers'] == 't', 1, 0)

# %%
# replace NaN with false in healthy_volunteers
df_merged_1123_seq['healthy_volunteers'] = df_merged_1123_seq['healthy_volunteers'].fillna('f')

# %%
# replace NaN with All in gender flag
df_merged_1123_seq['gender'] = df_merged_1123_seq['gender'].fillna('ALL')

# %%
# encode gender flag
# df_merged_1123_seq['gender'] = df_merged_1123_seq['gender'].replace({'FEMALE': 1, 'MALE': 2, 'ALL': 3})

# %%
df_merged_1123_seq['gender_f'] = df_merged_1123_seq['gender'].isin(['FEMALE', 'ALL']).astype(int)
df_merged_1123_seq['gender_m'] = df_merged_1123_seq['gender'].isin(['MALE', 'ALL']).astype(int)
df_merged_1123_seq = df_merged_1123_seq.drop(columns='gender')

# %%
df_merged_1123_seq.columns
# Out:
# Index(['Unnamed: 0', 'nct_id', 'intervention_type', 'description',
#        'trial_drug_cleaned', 'conditions', 'Drug Name', 'Highest Status',
#        'Other Drug Names', 'Originator Company',
#        ...
#        'LLM_GBT_4o_Human_Importance_Ratings', 'LLama3_2_Criteria_Robustness',
#        'Spacy_Pregnant_Women_Excluded', 'start_date_norm',
#        'primary_completion_date_norm', 'start_date_first',
#        'days_since_first_start', 'drug_outcome', 'gender_f', 'gender_m'],
#       dtype='object', length=145)

# %%
# replace NaN with 18 in min_age
df_merged_1123_seq['minimum_age_num'] = df_merged_1123_seq['minimum_age_num'].fillna(18)

# %%
# replace NaN with 99 in max_age
df_merged_1123_seq['maximum_age_num'] = df_merged_1123_seq['maximum_age_num'].fillna(99)

# %%
# replace NaN with 1 in number_of_facilities
df_merged_1123_seq['number_of_facilities'] = df_merged_1123_seq['number_of_facilities'].fillna(1)

# %%
# df_merged_1123_seq['nct_id_2'] = df_merged_1123_seq['nct_id'].str[-8:]

# %%
# calculate cumulative average enrollment size for each group of trials
rollup_df_1123_seq = df_merged_1123_seq.pipe(
    lambda x: x.assign(pcd=pd.to_datetime(x.primary_completion_date))
)[
    'trial_drug_cleaned disease_type new_therapy_area drug_outcome nct_id pcd '
    'enrollment actual_duration number_of_primary_outcomes_to_measure '
    'number_of_secondary_outcomes_to_measure number_of_arms adult '
    'child has_single_facility has_us_facility healthy_volunteers gender_f gender_m '
    'minimum_age_num maximum_age_num number_of_facilities '
    'Spacy_Pregnant_Women_Excluded LLama3_2_Criteria_Robustness '
    'LLM_GBT_4o_Human_Importance_Ratings'.split()
].drop_duplicates().sort_values(
    'trial_drug_cleaned disease_type new_therapy_area drug_outcome pcd'.split()
)

df_1123_trials_gb = rollup_df_1123_seq.groupby(
    'trial_drug_cleaned disease_type new_therapy_area drug_outcome'.split()
)

rollup_df_1123_seq = rollup_df_1123_seq.assign(
    cumsum_enrollment=df_1123_trials_gb.enrollment.expanding().sum().reset_index(
        [0, 1, 2, 3], drop=True
    ),
    cumavg_enrollment=df_1123_trials_gb.enrollment.expanding().mean().reset_index(
        [0, 1, 2, 3], drop=True
    ),
    cumsum_trial_duration=df_1123_trials_gb.actual_duration.expanding().sum().reset_index(
        [0, 1, 2, 3], drop=True
    ),
    cumavg_trial_duration=df_1123_trials_gb.actual_duration.expanding().mean().reset_index(
        [0, 1, 2, 3], drop=True
    ),
    cumulative_number_of_primary_outcomes_to_measure=df_1123_trials_gb.number_of_primary_outcomes_to_measure.expanding().sum().reset_index(
        [0, 1, 2, 3], drop=True
    ),
    cumulative_number_of_secondary_outcomes_to_measure=df_1123_trials_gb.number_of_secondary_outcomes_to_measure.expanding().sum().reset_index(
        [0, 1, 2, 3], drop=True
    ),
    cumulative_number_of_arms=df_1123_trials_gb.number_of_arms.expanding().sum().reset_index(
        [0, 1, 2, 3], drop=True
    ),
    cumulative_adult=df_1123_trials_gb.adult.expanding().max().reset_index(
        [0, 1, 2, 3], drop=True
    ),
    cumulative_child=df_1123_trials_gb.child.expanding().max().reset_index(
        [0, 1, 2, 3], drop=True
    ),
    cumulative_single_facility=df_1123_trials_gb.has_single_facility.expanding().max().reset_index(
        [0, 1, 2, 3], drop=True
    ),
    cumulative_us_facility=df_1123_trials_gb.has_us_facility.expanding().max().reset_index(
        [0, 1, 2, 3], drop=True
    ),
    cumulative_healthy_volunteers=df_1123_trials_gb.healthy_volunteers.expanding().max().reset_index(
        [0, 1, 2, 3], drop=True
    ),
    cumulative_gender_f=df_1123_trials_gb.gender_f.expanding().max().reset_index(
        [0, 1, 2, 3], drop=True
    ),
    cumulative_gender_m=df_1123_trials_gb.gender_m.expanding().max().reset_index(
        [0, 1, 2, 3], drop=True
    ),
    cumulative_min_age=df_1123_trials_gb.minimum_age_num.expanding().min().reset_index(
        [0, 1, 2, 3], drop=True
    ),
    cumulative_max_age=df_1123_trials_gb.maximum_age_num.expanding().max().reset_index(
        [0, 1, 2, 3], drop=True
    ),
    cumulative_number_of_facilities=df_1123_trials_gb.number_of_facilities.expanding().max().reset_index(
        [0, 1, 2, 3], drop=True
    ),
    cumulative_Spacy_Pregnant_Women_Excluded=df_1123_trials_gb.Spacy_Pregnant_Women_Excluded.expanding().max().reset_index(
        [0, 1, 2, 3], drop=True
    ),
    cumulative_LLama3_2_Criteria_Robustness=df_1123_trials_gb.LLama3_2_Criteria_Robustness.expanding().max().reset_index(
        [0, 1, 2, 3], drop=True
    ),
    cumulative_LLM_GPT_4o_Human_Importance_Ratings=df_1123_trials_gb.LLM_GBT_4o_Human_Importance_Ratings.expanding().max().reset_index(
        [0, 1, 2, 3], drop=True
    ),
    pair_trial_seq=df_1123_trials_gb.pcd.rank()
)

# %%
# if gender > 3, then force it to 3
# rollup_df_1123_seq.loc[rollup_df_1123_seq['cumulative_gender'] > 3, 'cumulative_gender'] = 3

# %%
# encode drug outcome
# rollup_df_1123_seq['drug_outcome'] = rollup_df_1123_seq['drug_outcome'].replace({'success': 1, 'failure': 0})

# %%
# remove duplicate drug_outcome by grouping and taking max of outcome
# rollup_df_1123_seq = rollup_df_1123_seq.loc[rollup_df_1123_seq.groupby(['trial_drug_cleaned', 'disease_type', 'nct_id', 'pcd'])['drug_outcome'].idxmax()]

# %%
rollup_df_1123_seq
# Out:
#        trial_drug_cleaned             disease_type  \
# 23972  123iiodometomidate                    Renal
# 23974  123iiodometomidate            Renal Disease
# 23971  123iiodometomidate       Unspecified Cancer
# 23973  123iiodometomidate  Unspecified Solid Tumor
# 5685        2deoxyglucose                 Prostate
# ...                   ...                      ...
# 3075       zoledronicacid  Unspecified Solid Tumor
# 20176          zonisamide       Alcohol Dependence
# 20173          zonisamide       Alcohol Dependence
# 20175          zonisamide       Alcohol Dependence
# 18336                zyh7             Dyslipidemia
#
#                    new_therapy_area  drug_outcome       nct_id        pcd  \
# 23972                      Oncology             0  NCT00454103 2008-12-31
# 23974                         Other             0  NCT00454103 2008-12-31
# 23971                      Oncology             0  NCT00454103 2008-12-31
# 23973                      Oncology             0  NCT00454103 2008-12-31
# 5685                       Oncology             0  NCT00633087 2011-03-31
# ...                             ...           ...          ...        ...
# 3075                       Oncology             1  NCT00558272 2010-01-31
# 20176  Psychiatry and Mental Health             1  NCT00406692 2008-08-31
# 20173  Psychiatry and Mental Health             1  NCT00862563 2013-08-31
# 20175  Psychiatry and Mental Health             1  NCT01847469 2019-01-01
# 18336                Cardiovascular             0  NCT01539616 2012-06-30
#
#        enrollment  actual_duration  number_of_primary_outcomes_to_measure  \
# 23972       122.0             21.0                                    1.0
# 23974       122.0             21.0                                    1.0
# 23971       122.0             21.0                                    1.0
# 23973       122.0             21.0                                    1.0
# 5685         12.0             52.0                                    1.0
# ...           ...              ...                                    ...
# 3075        139.0             23.0                                    1.0
# 20176        16.0             21.0                                    2.0
# 20173        85.0             51.0                                    1.0
# 20175        24.0             67.0                                    3.0
# 18336       109.0              7.0                                    1.0
#
#        number_of_secondary_outcomes_to_measure  number_of_arms  adult  child  \
# 23972                                      0.0             1.0      1      0
# 23974                                      0.0             1.0      1      0
# 23971                                      0.0             1.0      1      0
# 23973                                      0.0             1.0      1      0
# 5685                                       3.0             1.0      1      0
# ...                                        ...             ...    ...    ...
# 3075                                      16.0             2.0      1      0
# 20176                                      1.0             1.0      1      0
# 20173                                      7.0             4.0      1      0
# 20175                                      0.0             2.0      1      0
# 18336                                      1.0             4.0      1      0
#
#        has_single_facility  has_us_facility  healthy_volunteers  gender  \
# 23972                    1                0                   0       3
# 23974                    1                0                   0       3
# 23971                    1                0                   0       3
# 23973                    1                0                   0       3
# 5685                     1                1                   0       3
# ...                    ...              ...                 ...     ...
# 3075                     0                1                   0       3
# 20176                    1                1                   0       3
# 20173                    1                1                   0       3
# 20175                    1                1                   0       3
# 18336                    0                0                   0       3
#
#        minimum_age_num  maximum_age_num  number_of_facilities  \
# 23972             30.0             99.0                   1.0
# 23974             30.0             99.0                   1.0
# 23971             30.0             99.0                   1.0
# 23973             30.0             99.0                   1.0
# 5685              18.0             99.0                   1.0
# ...                ...              ...                   ...
# 3075              18.0             99.0                  28.0
# 20176             21.0             64.0                   1.0
# 20173             21.0             65.0                   1.0
# 20175             21.0             65.0                   1.0
# 18336             18.0             65.0                  18.0
#
#        Spacy_Pregnant_Women_Excluded  LLama3_2_Criteria_Robustness  \
# 23972                            0.0                           0.0
# 23974                            0.0                           0.0
# 23971                            0.0                           2.0
# 23973                            0.0                           0.0
# 5685                             1.0                           2.0
# ...                              ...                           ...
# 3075                             0.0                           0.0
# 20176                            1.0                           2.0
# 20173                            0.0                           0.0
# 20175                            1.0                           2.0
# 18336                            0.0                           2.0
#
#        LLM_GBT_4o_Human_Importance_Ratings  cumulative_enrollment  \
# 23972                                  0.0                  122.0
# 23974                                  0.0                  122.0
# 23971                                  0.0                  122.0
# 23973                                  0.0                  122.0
# 5685                                   1.0                   12.0
# ...                                    ...                    ...
# 3075                                   0.0                  139.0
# 20176                                  0.0                   16.0
# 20173                                  0.0                  101.0
# 20175                                  1.0                  125.0
# 18336                                  0.0                  109.0
#
#        cumulative_trial_duration  \
# 23972                       21.0
# 23974                       21.0
# 23971                       21.0
# 23973                       21.0
# 5685                        52.0
# ...                          ...
# 3075                        23.0
# 20176                       21.0
# 20173                       72.0
# 20175                      139.0
# 18336                        7.0
#
#        cumulative_number_of_primary_outcomes_to_measure  \
# 23972                                               1.0
# 23974                                               1.0
# 23971                                               1.0
# 23973                                               1.0
# 5685                                                1.0
# ...                                                 ...
# 3075                                                1.0
# 20176                                               2.0
# 20173                                               3.0
# 20175                                               6.0
# 18336                                               1.0
#
#        cumulative_number_of_secondary_outcomes_to_measure  \
# 23972                                                0.0
# 23974                                                0.0
# 23971                                                0.0
# 23973                                                0.0
# 5685                                                 3.0
# ...                                                  ...
# 3075                                                16.0
# 20176                                                1.0
# 20173                                                8.0
# 20175                                                8.0
# 18336                                                1.0
#
#        cumulative_number_of_arms  cumulative_adult  cumulative_child  \
# 23972                        1.0               1.0               0.0
# 23974                        1.0               1.0               0.0
# 23971                        1.0               1.0               0.0
# 23973                        1.0               1.0               0.0
# 5685                         1.0               1.0               0.0
# ...                          ...               ...               ...
# 3075                         2.0               1.0               0.0
# 20176                        1.0               1.0               0.0
# 20173                        5.0               1.0               0.0
# 20175                        7.0               1.0               0.0
# 18336                        4.0               1.0               0.0
#
#        cumulative_single_facility  cumulative_us_facility  \
# 23972                         1.0                     0.0
# 23974                         1.0                     0.0
# 23971                         1.0                     0.0
# 23973                         1.0                     0.0
# 5685                          1.0                     1.0
# ...                           ...                     ...
# 3075                          0.0                     1.0
# 20176                         1.0                     1.0
# 20173                         1.0                     1.0
# 20175                         1.0                     1.0
# 18336                         0.0                     0.0
#
#        cumulative_healthy_volunteers  cumulative_gender  cumulative_min_age  \
# 23972                            0.0                3.0                30.0
# 23974                            0.0                3.0                30.0
# 23971                            0.0                3.0                30.0
# 23973                            0.0                3.0                30.0
# 5685                             0.0                3.0                18.0
# ...                              ...                ...                 ...
# 3075                             0.0                3.0                18.0
# 20176                            0.0                3.0                21.0
# 20173                            0.0                3.0                21.0
# 20175                            0.0                3.0                21.0
# 18336                            0.0                3.0                18.0
#
#        cumulative_max_age  cumulative_number_of_facilities  \
# 23972                99.0                              1.0
# 23974                99.0                              1.0
# 23971                99.0                              1.0
# 23973                99.0                              1.0
# 5685                 99.0                              1.0
# ...                   ...                              ...
# 3075                 99.0                             28.0
# 20176                64.0                              1.0
# 20173                65.0                              1.0
# 20175                65.0                              1.0
# 18336                65.0                             18.0
#
#        cumulative_Spacy_Pregnant_Women_Excluded  \
# 23972                                       0.0
# 23974                                       0.0
# 23971                                       0.0
# 23973                                       0.0
# 5685                                        1.0
# ...                                         ...
# 3075                                        0.0
# 20176                                       1.0
# 20173                                       1.0
# 20175                                       1.0
# 18336                                       0.0
#
#        cumulative_LLama3_2_Criteria_Robustness  \
# 23972                                      0.0
# 23974                                      0.0
# 23971                                      2.0
# 23973                                      0.0
# 5685                                       2.0
# ...                                        ...
# 3075                                       0.0
# 20176                                      2.0
# 20173                                      2.0
# 20175                                      2.0
# 18336                                      2.0
#
#        cumulative_LLM_GBT_4o_Human_Importance_Ratings  pair_trial_seq
# 23972                                             0.0             1.0
# 23974                                             0.0             1.0
# 23971                                             0.0             1.0
# 23973                                             0.0             1.0
# 5685                                              1.0             1.0
# ...                                               ...             ...
# 3075                                              0.0             1.0
# 20176                                             0.0             1.0
# 20173                                             0.0             2.0
# 20175                                             1.0             3.0
# 18336                                             0.0             1.5
#
# [6333 rows x 41 columns]

# %%
# hot encode therapy area
rollup_df_1123_seq_final = pd.get_dummies(rollup_df_1123_seq, columns=['new_therapy_area'])
rollup_df_1123_seq_final.head()
# Out:
#        trial_drug_cleaned             disease_type  drug_outcome       nct_id  \
# 23867  123iiodometomidate                    Renal             0  NCT00454103
# 23869  123iiodometomidate            Renal Disease             0  NCT00454103
# 23866  123iiodometomidate       Unspecified Cancer             0  NCT00454103
# 23868  123iiodometomidate  Unspecified Solid Tumor             0  NCT00454103
# 2482        2deoxyglucose                 Prostate             0  NCT00633087
#
#              pcd  enrollment  actual_duration  \
# 23867 2008-12-31       122.0             21.0
# 23869 2008-12-31       122.0             21.0
# 23866 2008-12-31       122.0             21.0
# 23868 2008-12-31       122.0             21.0
# 2482  2011-03-31        12.0             52.0
#
#        number_of_primary_outcomes_to_measure  \
# 23867                                    1.0
# 23869                                    1.0
# 23866                                    1.0
# 23868                                    1.0
# 2482                                     1.0
#
#        number_of_secondary_outcomes_to_measure  number_of_arms  adult  child  \
# 23867                                      0.0             1.0      1      0
# 23869                                      0.0             1.0      1      0
# 23866                                      0.0             1.0      1      0
# 23868                                      0.0             1.0      1      0
# 2482                                       3.0             1.0      1      0
#
#        has_single_facility  has_us_facility  healthy_volunteers  gender_f  \
# 23867                    1                0                   0         1
# 23869                    1                0                   0         1
# 23866                    1                0                   0         1
# 23868                    1                0                   0         1
# 2482                     1                1                   0         1
#
#        gender_m  minimum_age_num  maximum_age_num  number_of_facilities  \
# 23867         1             30.0             99.0                   1.0
# 23869         1             30.0             99.0                   1.0
# 23866         1             30.0             99.0                   1.0
# 23868         1             30.0             99.0                   1.0
# 2482          1             18.0             99.0                   1.0
#
#        Spacy_Pregnant_Women_Excluded  LLama3_2_Criteria_Robustness  \
# 23867                            0.0                           0.0
# 23869                            0.0                           0.0
# 23866                            0.0                           2.0
# 23868                            0.0                           0.0
# 2482                             1.0                           2.0
#
#        LLM_GBT_4o_Human_Importance_Ratings  cumsum_enrollment  \
# 23867                                  0.0              122.0
# 23869                                  0.0              122.0
# 23866                                  0.0              122.0
# 23868                                  0.0              122.0
# 2482                                   1.0               12.0
#
#        cumavg_enrollment  cumsum_trial_duration  cumavg_trial_duration  \
# 23867              122.0                   21.0                   21.0
# 23869              122.0                   21.0                   21.0
# 23866              122.0                   21.0                   21.0
# 23868              122.0                   21.0                   21.0
# 2482                12.0                   52.0                   52.0
#
#        cumulative_number_of_primary_outcomes_to_measure  \
# 23867                                               1.0
# 23869                                               1.0
# 23866                                               1.0
# 23868                                               1.0
# 2482                                                1.0
#
#        cumulative_number_of_secondary_outcomes_to_measure  \
# 23867                                                0.0
# 23869                                                0.0
# 23866                                                0.0
# 23868                                                0.0
# 2482                                                 3.0
#
#        cumulative_number_of_arms  cumulative_adult  cumulative_child  \
# 23867                        1.0               1.0               0.0
# 23869                        1.0               1.0               0.0
# 23866                        1.0               1.0               0.0
# 23868                        1.0               1.0               0.0
# 2482                         1.0               1.0               0.0
#
#        cumulative_single_facility  cumulative_us_facility  \
# 23867                         1.0                     0.0
# 23869                         1.0                     0.0
# 23866                         1.0                     0.0
# 23868                         1.0                     0.0
# 2482                          1.0                     1.0
#
#        cumulative_healthy_volunteers  cumulative_gender_f  \
# 23867                            0.0                  1.0
# 23869                            0.0                  1.0
# 23866                            0.0                  1.0
# 23868                            0.0                  1.0
# 2482                             0.0                  1.0
#
#        cumulative_gender_m  cumulative_min_age  cumulative_max_age  \
# 23867                  1.0                30.0                99.0
# 23869                  1.0                30.0                99.0
# 23866                  1.0                30.0                99.0
# 23868                  1.0                30.0                99.0
# 2482                   1.0                18.0                99.0
#
#        cumulative_number_of_facilities  \
# 23867                              1.0
# 23869                              1.0
# 23866                              1.0
# 23868                              1.0
# 2482                               1.0
#
#        cumulative_Spacy_Pregnant_Women_Excluded  \
# 23867                                       0.0
# 23869                                       0.0
# 23866                                       0.0
# 23868                                       0.0
# 2482                                        1.0
#
#        cumulative_LLama3_2_Criteria_Robustness  \
# 23867                                      0.0
# 23869                                      0.0
# 23866                                      2.0
# 23868                                      0.0
# 2482                                       2.0
#
#        cumulative_LLM_GPT_4o_Human_Importance_Ratings  pair_trial_seq  \
# 23867                                             0.0             1.0
# 23869                                             0.0             1.0
# 23866                                             0.0             1.0
# 23868                                             0.0             1.0
# 2482                                              1.0             1.0
#
#        new_therapy_area_Autoimmune  new_therapy_area_Bone  \
# 23867                        False                  False
# 23869                        False                  False
# 23866                        False                  False
# 23868                        False                  False
# 2482                         False                  False
#
#        new_therapy_area_Cardiovascular  new_therapy_area_Dermatology  \
# 23867                            False                         False
# 23869                            False                         False
# 23866                            False                         False
# 23868                            False                         False
# 2482                             False                         False
#
#        new_therapy_area_Endocrinology  new_therapy_area_Gastrointestinal  \
# 23867                           False                              False
# 23869                           False                              False
# 23866                           False                              False
# 23868                           False                              False
# 2482                            False                              False
#
#        new_therapy_area_Genetic and Rare Diseases  \
# 23867                                       False
# 23869                                       False
# 23866                                       False
# 23868                                       False
# 2482                                        False
#
#        new_therapy_area_Hematology  new_therapy_area_Hepatic diseases  \
# 23867                        False                              False
# 23869                        False                              False
# 23866                        False                              False
# 23868                        False                              False
# 2482                         False                              False
#
#        new_therapy_area_Infections (bacterial)  \
# 23867                                    False
# 23869                                    False
# 23866                                    False
# 23868                                    False
# 2482                                     False
#
#        new_therapy_area_Infections (viral)  \
# 23867                                False
# 23869                                False
# 23866                                False
# 23868                                False
# 2482                                 False
#
#        new_therapy_area_Infectious Diseases  \
# 23867                                 False
# 23869                                 False
# 23866                                 False
# 23868                                 False
# 2482                                  False
#
#        new_therapy_area_Metabolic disorders  new_therapy_area_Neurology  \
# 23867                                 False                       False
# 23869                                 False                       False
# 23866                                 False                       False
# 23868                                 False                       False
# 2482                                  False                       False
#
#        new_therapy_area_Neuroscience (non-progressive)  \
# 23867                                            False
# 23869                                            False
# 23866                                            False
# 23868                                            False
# 2482                                             False
#
#        new_therapy_area_Oncology  new_therapy_area_Ophthalmology  \
# 23867                       True                           False
# 23869                      False                           False
# 23866                       True                           False
# 23868                       True                           False
# 2482                        True                           False
#
#        new_therapy_area_Other  new_therapy_area_Pain  \
# 23867                   False                  False
# 23869                    True                  False
# 23866                   False                  False
# 23868                   False                  False
# 2482                    False                  False
#
#        new_therapy_area_Progressive neurological disorders  \
# 23867                                              False
# 23869                                              False
# 23866                                              False
# 23868                                              False
# 2482                                               False
#
#        new_therapy_area_Psychiatry and Mental Health  \
# 23867                                          False
# 23869                                          False
# 23866                                          False
# 23868                                          False
# 2482                                           False
#
#        new_therapy_area_Respiratory  new_therapy_area_Rheumatology  \
# 23867                         False                          False
# 23869                         False                          False
# 23866                         False                          False
# 23868                         False                          False
# 2482                          False                          False
#
#        new_therapy_area_Urology and Reproductive Health
# 23867                                             False
# 23869                                             False
# 23866                                             False
# 23868                                             False
# 2482                                              False

# %%
rollup_df_1123_seq_final.to_csv('rollup_df_1123_seq_final.txt', sep='|', index=True)

# %%
# !cp rollup_df_1123_seq_final.txt /content/drive/MyDrive/Capstone2024/Datasets/nov_23/

# %%
# df_merged_1123_seq['number_of_facilities'].unique()
